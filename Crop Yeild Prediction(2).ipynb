# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/RISHABH/Documents/reportfarmers.csv')

# %%
df.head(5)
# Out:
#    Location_Code  Property_Size_Ha Crop_Group_Name  Crop_Group_Code  \
# 0              4              0.80         Cereals              600
# 1              4              0.30      Condiments              400
# 2              4              9.00      Condiments              400
# 3              4             13.25      Condiments              400
# 4              4              5.06      Condiments              400
#
#    Parish_Code  Parish_Extension_Code District     Parish  \
# 0            2                      1  BELMONT  ST.ANDREW
# 1            2                      1  BELMONT  ST.ANDREW
# 2            2                      1  BELMONT  ST.ANDREW
# 3            2                      1  BELMONT  ST.ANDREW
# 4            2                      1  BELMONT  ST.ANDREW
#
#   Parish_Extension_Name        Crop_Name  Crop_Type_Code  Crop_Total_Area_Ha  \
# 0       SALISBURY PLAIN  Corn (Ordinary)              90                0.06
# ...

# %%
df[df['Crop_Type_Code']==70]['Crop_Name']
# Out:
# 2        Ginger
# 174      Ginger
# 208      Ginger
# 244      Ginger
# 265      Ginger
# 311      Ginger
# 325      Ginger
# 364      Ginger
# 394      Ginger
# 478      Ginger
# 507      Ginger
# 517      Ginger
# 531      Ginger
# 544      Ginger
# 578      Ginger
# 596      Ginger
# 610      Ginger
# 617      Ginger
# 698      Ginger
# 709      Ginger
# 795      Ginger
# 899      Ginger
# 968      Ginger
# 1071     Ginger
# 1097     Ginger
# 1164     Ginger
# 1205     Ginger
# 1256     Ginger
# 1329     Ginger
# 1362     Ginger
#           ...
# 80908    Ginger
# 80945    Ginger
# 81134    Ginger
# 81278    Ginger
# 81291    Ginger
# 81586    Ginger
# 81639    Ginger
# 81723    Ginger
# 81774    Ginger
# 81924    Ginger
# 81981    Ginger
# 82006    Ginger
# 82332    Ginger
# 82424    Ginger
# 82535    Ginger
# 82674    Ginger
# 83261    Ginger
# 83272    Ginger
# 83288    Ginger
# 83420    Ginger
# 83491    Ginger
# 83567    Ginger
# 83598    Ginger
# 83627    Ginger
# ...

# %%
df = df.drop(df.columns[[0,2,3,4,5,6,7,8,9,13]], axis=1)

# %%
df.head(10)
# Out:
#    Property_Size_Ha  Crop_Type_Code  Crop_Total_Area_Ha  Crop_Count_Total
# 0              0.80              90                0.06               NaN
# 1              0.30              69                0.01               5.0
# 2              9.00              70                2.01               0.0
# 3             13.25              74                3.31             100.0
# 4              5.06              76                0.28               0.0
# 5              8.28              80                0.97             350.0
# 6              3.03              39                0.82               0.0
# 7              9.83              40                2.12              52.0
# 8              4.05              36                0.03             600.0
# 9              0.40              21                0.01               3.0

# %%
df.sort_values("Crop_Type_Code", axis = 0, ascending = True, 
                 inplace = True, na_position ='last')

# %%
df
# Out:
#        Property_Size_Ha  Crop_Type_Code  Crop_Total_Area_Ha  Crop_Count_Total
# 74620             10.11               1                0.03               5.0
# 27716             80.94               1               12.14               0.0
# 2224               1.21               1                0.12               3.0
# 62360              4.05               1                0.01               0.0
# 5855               4.44               1                0.06              12.0
# 57107              0.20               1                0.01               0.0
# 19521              2.02               1                0.40               NaN
# 62401              3.74               1                0.01               0.0
# 53695              0.81               1                0.04               0.0
# 19458              1.90               1                0.03               NaN
# 27631              2.43               1                0.01               0.0
# ...

# %%
sg=df.loc[df['Crop_Type_Code'] == 70]

# %%
sg
# Out:
#        Property_Size_Ha  Crop_Type_Code  Crop_Total_Area_Ha  Crop_Count_Total
# 36919              3.85              70                0.05               0.0
# 39479            163.89              70                1.13               0.0
# 5599              10.31              70                2.03             112.0
# 67846              0.40              70                0.12               0.0
# 36954             20.15              70                2.19               0.0
# 40890              7.28              70                0.40             350.0
# 35757              2.42              70                0.14               0.0
# 81981              5.67              70                1.62               0.0
# 33907              0.40              70                0.01               0.0
# 17704              8.23              70                0.48               0.0
# 81134              5.26              70                0.04               NaN
# ...

# %%
gf=sg.set_index('Crop_Type_Code')

# %%
gf
# Out:
#                 Property_Size_Ha  Crop_Total_Area_Ha  Crop_Count_Total
# Crop_Type_Code
# 70                          3.85                0.05               0.0
# 70                        163.89                1.13               0.0
# 70                         10.31                2.03             112.0
# 70                          0.40                0.12               0.0
# 70                         20.15                2.19               0.0
# 70                          7.28                0.40             350.0
# 70                          2.42                0.14               0.0
# 70                          5.67                1.62               0.0
# 70                          0.40                0.01               0.0
# 70                          8.23                0.48               0.0
# 70                          5.26                0.04               NaN
# 70                          0.20                0.20               0.0
# ...

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values = 'NaN', strategy = 'median', axis = 0)
imputer = imputer.fit(gf.iloc[:, 2:3])
gf.iloc[:, 2:3] = imputer.transform(gf.iloc[:, 2:3])
# Out:
# E:\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
gf
# Out:
#                 Property_Size_Ha  Crop_Total_Area_Ha  Crop_Count_Total
# Crop_Type_Code
# 70                          3.85                0.05               0.0
# 70                        163.89                1.13               0.0
# 70                         10.31                2.03             112.0
# 70                          0.40                0.12               0.0
# 70                         20.15                2.19               0.0
# 70                          7.28                0.40             350.0
# 70                          2.42                0.14               0.0
# 70                          5.67                1.62               0.0
# 70                          0.40                0.01               0.0
# 70                          8.23                0.48               0.0
# 70                          5.26                0.04               0.0
# 70                          0.20                0.20               0.0
# ...

# %%
gf.insert(3, "Crop_Name", 'Ginger')

# %%
gf
# Out:
#                 Property_Size_Ha  Crop_Total_Area_Ha  Crop_Count_Total  \
# Crop_Type_Code
# 70                          3.85                0.05               0.0
# 70                        163.89                1.13               0.0
# 70                         10.31                2.03             112.0
# 70                          0.40                0.12               0.0
# 70                         20.15                2.19               0.0
# 70                          7.28                0.40             350.0
# 70                          2.42                0.14               0.0
# 70                          5.67                1.62               0.0
# 70                          0.40                0.01               0.0
# 70                          8.23                0.48               0.0
# 70                          5.26                0.04               0.0
# 70                          0.20                0.20               0.0
# ...

# %%
gf['Yeild(Qunitol/Heactare)'] =(gf['Crop_Count_Total']/gf['Crop_Total_Area_Ha'])*(0.000741)

# %%
gf
# Out:
#                 Property_Size_Ha  Crop_Total_Area_Ha  Crop_Count_Total  \
# Crop_Type_Code
# 70                          3.85                0.05               0.0
# 70                        163.89                1.13               0.0
# 70                         10.31                2.03             112.0
# 70                          0.40                0.12               0.0
# 70                         20.15                2.19               0.0
# 70                          7.28                0.40             350.0
# 70                          2.42                0.14               0.0
# 70                          5.67                1.62               0.0
# 70                          0.40                0.01               0.0
# 70                          8.23                0.48               0.0
# 70                          5.26                0.04               0.0
# 70                          0.20                0.20               0.0
# ...

# %%
X=gf.iloc[:,0:3]
X
# Out:
#                 Property_Size_Ha  Crop_Total_Area_Ha  Crop_Count_Total
# Crop_Type_Code
# 70                          3.85                0.05               0.0
# 70                        163.89                1.13               0.0
# 70                         10.31                2.03             112.0
# 70                          0.40                0.12               0.0
# 70                         20.15                2.19               0.0
# 70                          7.28                0.40             350.0
# 70                          2.42                0.14               0.0
# 70                          5.67                1.62               0.0
# 70                          0.40                0.01               0.0
# 70                          8.23                0.48               0.0
# 70                          5.26                0.04               0.0
# 70                          0.20                0.20               0.0
# ...

# %%
y=gf.iloc[:,4]

# %%
y
# Out:
# Crop_Type_Code
# 70    0.000000
# 70    0.000000
# 70    0.040883
# 70    0.000000
# 70    0.000000
# 70    0.648375
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.068358
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
#         ...
# 70    0.000000
# 70    0.000000
# 70    4.234286
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# 70    0.000000
# ...

# %%
from sklearn.model_selection import train_test_split 
X_train , X_test, y_train , y_test =train_test_split(X,y,test_size =0.25 ,random_state = 2 )

# %% [markdown]
# ### Decision Tree Regression

# %%
X_train
# Out:
#                 Property_Size_Ha  Crop_Total_Area_Ha  Crop_Count_Total
# Crop_Type_Code
# 70                         22.66                0.13               0.0
# 70                          0.81                0.01               0.0
# 70                        121.41                1.62               0.0
# 70                         37.23                1.02               0.0
# 70                          2.91                0.83               0.0
# 70                         16.00                0.01              50.0
# 70                          5.67                1.62               0.0
# 70                          0.81                0.08               0.0
# 70                          2.23                0.04               0.0
# 70                          0.61                0.06               0.0
# 70                          9.52                2.87               0.0
# 70                         32.37                1.21               0.0
# ...

# %%
y_train
# Out:
# Crop_Type_Code
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    3.705
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
#       ...
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# 70    0.000
# Name: Yeild(Qunitol/Heactare), Length: 552, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=0, splitter='best')

# %%
y_pred  =  regressor.predict(X_test)

# %%
y_pred,y_test
# Out:
# (array([3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.65925926e-01, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
#         3.62716579e-06, 3.62716579e-06, 3.62716579e-06, 3.62716579e-06,
# ...
